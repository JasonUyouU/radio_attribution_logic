# %%
import pandas_gbq
import pandas as pd
import numpy as np

# %%
project_id = 'marketing-bigquery-project'

# %%
df = pandas_gbq.read_gbq("SELECT * FROM `marketing-bigquery-project.Spike_Attribution_Model.q3_sepinc_2020_all_dma_base` ORDER BY DMA ASC, pasre_date ASC", project_id = project_id)

# %%
df['Ad_played'] = np.where(df['Ads'] != 0, True, False)

# %% [markdown]
# Calculation for the baseline.  Baseline is calculated when there is an Ad and there has been no other Ad in the last 10 minutes.  .shift() is a function to retrieve values from previous rows

# %%
df['Baseline'] = np.where((df['Ads'] != 0) & (df['Ads'].shift(1) == 0) & 
                          (df['Ads'].shift(2) == 0) & (df['Ads'].shift(3) == 0) & 
                          (df['Ads'].shift(4) == 0) & (df['Ads'].shift(5) == 0) & 
                          (df['Ads'].shift(6) == 0) & (df['Ads'].shift(7) == 0) & 
                          (df['Ads'].shift(8) == 0) & (df['Ads'].shift(9) == 0) & (df['Ads'].shift(10) == 0), 
                          (df['visits'].shift(1) + df['visits'].shift(2) + 
                           df['visits'].shift(3) + df['visits'].shift(4) + 
                           df['visits'].shift(5) + df['visits'].shift(6) + 
                           df['visits'].shift(7) + df['visits'].shift(8) + 
                           df['visits'].shift(9) + df['visits'].shift(10))/10, 0)

# %% [markdown]
# Replaces the baseline with the previous non-zero baseline

# %%
df['Baseline'] = np.where((df['Ad_played'] == True) & (df['Baseline'] == 0), 
                          df['Baseline'].replace(to_replace=0, method='ffill'), df['Baseline'])

# %% [markdown]
# Logic for 0th attriution

# %%
df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 0), df['visits'] - df['Baseline'], 0)

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 1), (df['visits'] - df['Baseline']) * .59, df['attribute_0'])

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 2), (df['visits'] - df['Baseline']) * .41, df['attribute_0'])

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 3), (df['visits'] - df['Baseline']) * .32, df['attribute_0'])

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 4), (df['visits'] - df['Baseline']) * .26, df['attribute_0'])

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 5), (df['visits'] - df['Baseline']) * .22, df['attribute_0'])

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 6), (df['visits'] - df['Baseline']) * .19, df['attribute_0'])

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 7), (df['visits'] - df['Baseline']) * .17, df['attribute_0'])

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 8), (df['visits'] - df['Baseline']) * .15, df['attribute_0'])

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 9), (df['visits'] - df['Baseline']) * .13, df['attribute_0'])

df['attribute_0'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) + df['Ads'].shift(10) == 10), (df['visits'] - df['Baseline']) * .12, df['attribute_0'])

# %% [markdown]
# Logic for 1st attribution

# %%
df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 0) & (df['Ads'].shift(-1) == 0), df['visits'].shift(-1) - df['Baseline'], 0)

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 0) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .41, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 1) & (df['Ads'].shift(-1) == 0), (df['visits'].shift(-1) - df['Baseline']) * .59, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 1) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .33, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 2) & (df['Ads'].shift(-1) == 0), (df['visits'].shift(-1) - df['Baseline']) * .41, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 2) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .27, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 3) & (df['Ads'].shift(-1) == 0), (df['visits'].shift(-1) - df['Baseline']) * .32, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 3) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .22, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 4) & (df['Ads'].shift(-1) == 0), (df['visits'].shift(-1) - df['Baseline']) * .26, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 4) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .19, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 5) & (df['Ads'].shift(-1) == 0), (df['visits'].shift(-1) - df['Baseline']) * .22, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 5) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .17, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 6) & (df['Ads'].shift(-1) == 0), (df['visits'].shift(-1) - df['Baseline']) * .19, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 6) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .15, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 7) & (df['Ads'].shift(-1) == 0), (df['visits'].shift(-1) - df['Baseline']) * .17, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 7) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .14, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 8) & (df['Ads'].shift(-1) == 0), (df['visits'].shift(-1) - df['Baseline']) * .15, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 8) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .12, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 9) & (df['Ads'].shift(-1) == 0), (df['visits'].shift(-1) - df['Baseline']) * .13, df['attribute_1'])

df['attribute_1'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                           df['Ads'].shift(3) + df['Ads'].shift(4) + 
                           df['Ads'].shift(5) + df['Ads'].shift(6) + 
                           df['Ads'].shift(7) + df['Ads'].shift(8) + 
                           df['Ads'].shift(9) == 9) & (df['Ads'].shift(-1) == 1), (df['visits'].shift(-1) - df['Baseline']) * .11, df['attribute_1'])

# %% [markdown]
# Logic for 2nd attribution

# %%
df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 0), df['visits'].shift(-2) - df['Baseline'], 0)

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 1), (df['visits'].shift(-2) - df['Baseline']) * .41, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 2), (df['visits'].shift(-2) - df['Baseline']) * .26, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 0), (df['visits'].shift(-2) - df['Baseline']) * .59, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 1), (df['visits'].shift(-2) - df['Baseline']) * .33, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 2), (df['visits'].shift(-2) - df['Baseline']) * .22, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 0), (df['visits'].shift(-2) - df['Baseline']) * .41, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 1), (df['visits'].shift(-2) - df['Baseline']) * .27, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 2), (df['visits'].shift(-2) - df['Baseline']) * .20, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 0), (df['visits'].shift(-2) - df['Baseline']) * .32, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 1), (df['visits'].shift(-2) - df['Baseline']) * .22, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 2), (df['visits'].shift(-2) - df['Baseline']) * .17, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 0), (df['visits'].shift(-2) - df['Baseline']) * .26, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 1), (df['visits'].shift(-2) - df['Baseline']) * .19, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 2), (df['visits'].shift(-2) - df['Baseline']) * .15, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 5) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 0), (df['visits'].shift(-2) - df['Baseline']) * .22, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 5) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 1), (df['visits'].shift(-2) - df['Baseline']) * .17, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 5) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 2), (df['visits'].shift(-2) - df['Baseline']) * .14, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 6) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 0), (df['visits'].shift(-2) - df['Baseline']) * .19, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 6) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 1), (df['visits'].shift(-2) - df['Baseline']) * .15, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 6) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 2), (df['visits'].shift(-2) - df['Baseline']) * .13, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 7) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 0), (df['visits'].shift(-2) - df['Baseline']) * .17, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 7) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 1), (df['visits'].shift(-2) - df['Baseline']) * .14, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 7) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 2), (df['visits'].shift(-2) - df['Baseline']) * .12, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 8) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 0), (df['visits'].shift(-2) - df['Baseline']) * .15, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 8) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 1), (df['visits'].shift(-2) - df['Baseline']) * .12, df['attribute_2'])

df['attribute_2'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) + df['Ads'].shift(8) == 8) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) == 2), (df['visits'].shift(-2) - df['Baseline']) * .11, df['attribute_2'])

# %% [markdown]
# Logic for 3rd attribution

# %%
df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 0), df['visits'].shift(-3) - df['Baseline'], 0)

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 1), (df['visits'].shift(-3) - df['Baseline']) * .41, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 2), (df['visits'].shift(-3) - df['Baseline']) * .26, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 3), (df['visits'].shift(-3) - df['Baseline']) * .19, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 0), (df['visits'].shift(-3) - df['Baseline']) * .59, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 1), (df['visits'].shift(-3) - df['Baseline']) * .33, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 2), (df['visits'].shift(-3) - df['Baseline']) * .22, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 3), (df['visits'].shift(-3) - df['Baseline']) * .17, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 0), (df['visits'].shift(-3) - df['Baseline']) * .41, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 1), (df['visits'].shift(-3) - df['Baseline']) * .27, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 2), (df['visits'].shift(-3) - df['Baseline']) * .20, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 3), (df['visits'].shift(-3) - df['Baseline']) * .15, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 0), (df['visits'].shift(-3) - df['Baseline']) * .32, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 1), (df['visits'].shift(-3) - df['Baseline']) * .22, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 2), (df['visits'].shift(-3) - df['Baseline']) * .17, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 3), (df['visits'].shift(-3) - df['Baseline']) * .14, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 0), (df['visits'].shift(-3) - df['Baseline']) * .26, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 1), (df['visits'].shift(-3) - df['Baseline']) * .19, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 2), (df['visits'].shift(-3) - df['Baseline']) * .15, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 3), (df['visits'].shift(-3) - df['Baseline']) * .13, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 0), (df['visits'].shift(-3) - df['Baseline']) * .22, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 1), (df['visits'].shift(-3) - df['Baseline']) * .17, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 2), (df['visits'].shift(-3) - df['Baseline']) * .14, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 3), (df['visits'].shift(-3) - df['Baseline']) * .12, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 6) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 0), (df['visits'].shift(-3) - df['Baseline']) * .19, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 6) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 1), (df['visits'].shift(-3) - df['Baseline']) * .15, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 6) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 2), (df['visits'].shift(-3) - df['Baseline']) * .13, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 6) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 3), (df['visits'].shift(-3) - df['Baseline']) * .11, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 7) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 0), (df['visits'].shift(-3) - df['Baseline']) * .17, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 7) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 1), (df['visits'].shift(-3) - df['Baseline']) * .14, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 7) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 2), (df['visits'].shift(-3) - df['Baseline']) * .12, df['attribute_3'])

df['attribute_3'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) + 
                              df['Ads'].shift(7) == 7) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) == 3), (df['visits'].shift(-3) - df['Baseline']) * .10, df['attribute_3'])

# %% [markdown]
# Logic for 4th attribution

# %%
df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 0), df['visits'].shift(-4) - df['Baseline'], 0)

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 1), (df['visits'].shift(-4) - df['Baseline']) * .41, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 2), (df['visits'].shift(-4) - df['Baseline']) * .26, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 3), (df['visits'].shift(-4) - df['Baseline']) * .19, df['attribute_4'])
df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 4), (df['visits'].shift(-4) - df['Baseline']) * .15, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 0), (df['visits'].shift(-4) - df['Baseline']) * .59, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 1), (df['visits'].shift(-4) - df['Baseline']) * .33, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 2), (df['visits'].shift(-4) - df['Baseline']) * .22, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 3), (df['visits'].shift(-4) - df['Baseline']) * .17, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 4), (df['visits'].shift(-4) - df['Baseline']) * .14, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 0), (df['visits'].shift(-4) - df['Baseline']) * .41, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 1), (df['visits'].shift(-4) - df['Baseline']) * .27, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 2), (df['visits'].shift(-4) - df['Baseline']) * .20, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 3), (df['visits'].shift(-4) - df['Baseline']) * .15, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 4), (df['visits'].shift(-4) - df['Baseline']) * .13, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 0), (df['visits'].shift(-4) - df['Baseline']) * .32, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 1), (df['visits'].shift(-4) - df['Baseline']) * .22, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 2), (df['visits'].shift(-4) - df['Baseline']) * .17, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 3), (df['visits'].shift(-4) - df['Baseline']) * .14, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 4), (df['visits'].shift(-4) - df['Baseline']) * .12, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 0), (df['visits'].shift(-4) - df['Baseline']) * .26, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 1), (df['visits'].shift(-4) - df['Baseline']) * .19, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 2), (df['visits'].shift(-4) - df['Baseline']) * .15, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 3), (df['visits'].shift(-4) - df['Baseline']) * .13, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 4), (df['visits'].shift(-4) - df['Baseline']) * .11, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 5) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 0), (df['visits'].shift(-4) - df['Baseline']) * .22, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 5) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 1), (df['visits'].shift(-4) - df['Baseline']) * .17, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 5) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 2), (df['visits'].shift(-4) - df['Baseline']) * .14, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 5) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 3), (df['visits'].shift(-4) - df['Baseline']) * .12, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 5) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 4), (df['visits'].shift(-4) - df['Baseline']) * .10, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 6) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 0), (df['visits'].shift(-4) - df['Baseline']) * .19, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 6) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 1), (df['visits'].shift(-4) - df['Baseline']) * .15, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 6) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 2), (df['visits'].shift(-4) - df['Baseline']) * .13, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 6) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 3), (df['visits'].shift(-4) - df['Baseline']) * .11, df['attribute_4'])

df['attribute_4'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) + df['Ads'].shift(6) == 6) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) == 4), (df['visits'].shift(-4) - df['Baseline']) * .09, df['attribute_4'])

# %% [markdown]
# Logic for 5th attribution

# %%
df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 0), df['visits'].shift(-5) - df['Baseline'], 0)

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 1), (df['visits'].shift(-5) - df['Baseline']) * .41, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 2), (df['visits'].shift(-5) - df['Baseline']) * .26, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 3), (df['visits'].shift(-5) - df['Baseline']) * .19, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 4), (df['visits'].shift(-5) - df['Baseline']) * .15, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 5), (df['visits'].shift(-5) - df['Baseline']) * .12, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 0), (df['visits'].shift(-5) - df['Baseline']) * .59, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 1), (df['visits'].shift(-5) - df['Baseline']) * .33, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 2), (df['visits'].shift(-5) - df['Baseline']) * .22, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 3), (df['visits'].shift(-5) - df['Baseline']) * .17, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 4), (df['visits'].shift(-5) - df['Baseline']) * .14, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 5), (df['visits'].shift(-5) - df['Baseline']) * .11, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 0), (df['visits'].shift(-5) - df['Baseline']) * .41, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 1), (df['visits'].shift(-5) - df['Baseline']) * .27, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 2), (df['visits'].shift(-5) - df['Baseline']) * .20, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 3), (df['visits'].shift(-5) - df['Baseline']) * .15, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 4), (df['visits'].shift(-5) - df['Baseline']) * .13, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 5), (df['visits'].shift(-5) - df['Baseline']) * .11, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 0), (df['visits'].shift(-5) - df['Baseline']) * .32, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 1), (df['visits'].shift(-5) - df['Baseline']) * .22, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 2), (df['visits'].shift(-5) - df['Baseline']) * .17, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 3), (df['visits'].shift(-5) - df['Baseline']) * .14, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 4), (df['visits'].shift(-5) - df['Baseline']) * .12, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 5), (df['visits'].shift(-5) - df['Baseline']) * .10, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 0), (df['visits'].shift(-5) - df['Baseline']) * .26, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 1), (df['visits'].shift(-5) - df['Baseline']) * .19, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 2), (df['visits'].shift(-5) - df['Baseline']) * .15, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 3), (df['visits'].shift(-5) - df['Baseline']) * .13, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 4), (df['visits'].shift(-5) - df['Baseline']) * .11, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 4) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 5), (df['visits'].shift(-5) - df['Baseline']) * .09, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 0), (df['visits'].shift(-5) - df['Baseline']) * .22, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 1), (df['visits'].shift(-5) - df['Baseline']) * .17, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 2), (df['visits'].shift(-5) - df['Baseline']) * .14, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 3), (df['visits'].shift(-5) - df['Baseline']) * .12, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 4), (df['visits'].shift(-5) - df['Baseline']) * .10, df['attribute_5'])

df['attribute_5'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) + 
                              df['Ads'].shift(5) == 5) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) == 5), (df['visits'].shift(-5) - df['Baseline']) * .09, df['attribute_5'])

# %% [markdown]
# Logic for 6th attribution

# %%
df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 0), df['visits'].shift(-6) - df['Baseline'], 0)

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 1), (df['visits'].shift(-6) - df['Baseline']) * .41, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 2), (df['visits'].shift(-6) - df['Baseline']) * .26, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 3), (df['visits'].shift(-6) - df['Baseline']) * .19, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 4), (df['visits'].shift(-6) - df['Baseline']) * .15, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 5), (df['visits'].shift(-6) - df['Baseline']) * .12, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 6), (df['visits'].shift(-6) - df['Baseline']) * .10, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 0), (df['visits'].shift(-6) - df['Baseline']) * .59, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 1), (df['visits'].shift(-6) - df['Baseline']) * .33, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 2), (df['visits'].shift(-6) - df['Baseline']) * .22, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 3), (df['visits'].shift(-6) - df['Baseline']) * .17, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 4), (df['visits'].shift(-6) - df['Baseline']) * .14, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 5), (df['visits'].shift(-6) - df['Baseline']) * .11, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 6), df['visits'].shift(-6) - df['Baseline'] * .10, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 0), (df['visits'].shift(-6) - df['Baseline']) * .41, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 1), (df['visits'].shift(-6) - df['Baseline']) * .27, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 2), (df['visits'].shift(-6) - df['Baseline']) * .20, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 3), (df['visits'].shift(-6) - df['Baseline']) * .15, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 4), (df['visits'].shift(-6) - df['Baseline']) * .13, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 5), (df['visits'].shift(-6) - df['Baseline']) * .11, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 6), (df['visits'].shift(-6) - df['Baseline']) * .09, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 0), (df['visits'].shift(-6) - df['Baseline']) * .32, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 1), (df['visits'].shift(-6) - df['Baseline']) * .22, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 2), (df['visits'].shift(-6) - df['Baseline']) * .17, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 3), (df['visits'].shift(-6) - df['Baseline']) * .14, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 4), (df['visits'].shift(-6) - df['Baseline']) * .12, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 5), (df['visits'].shift(-6) - df['Baseline']) * .10, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 3) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 6), (df['visits'].shift(-6) - df['Baseline']) * .09, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 0), (df['visits'].shift(-6) - df['Baseline']) * .26, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 1), (df['visits'].shift(-6) - df['Baseline']) * .19, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 2), (df['visits'].shift(-6) - df['Baseline']) * .15, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 3), (df['visits'].shift(-6) - df['Baseline']) * .13, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 4), (df['visits'].shift(-6) - df['Baseline']) * .11, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 5), (df['visits'].shift(-6) - df['Baseline']) * .09, df['attribute_6'])

df['attribute_6'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) + df['Ads'].shift(4) == 4) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) + 
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) == 6), (df['visits'].shift(-6) - df['Baseline']) * .08, df['attribute_6'])

# %% [markdown]
# Logic for 7th Attribution

# %%
df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 0), df['visits'].shift(-7) - df['Baseline'], 0)

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 1), (df['visits'].shift(-7) - df['Baseline']) * .41, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 2), (df['visits'].shift(-7) - df['Baseline']) * .26, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 3), (df['visits'].shift(-7) - df['Baseline']) * .19, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 4), (df['visits'].shift(-7) - df['Baseline']) * .15, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 5), (df['visits'].shift(-7) - df['Baseline']) * .12, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 6), (df['visits'].shift(-7) - df['Baseline']) * .10, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 0) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 7), (df['visits'].shift(-7) - df['Baseline']) * .09, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 0), (df['visits'].shift(-7) - df['Baseline']) * .59, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 1), (df['visits'].shift(-7) - df['Baseline']) * .33, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 2), (df['visits'].shift(-7) - df['Baseline']) * .22, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 3), (df['visits'].shift(-7) - df['Baseline']) * .17, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 4), (df['visits'].shift(-7) - df['Baseline']) * .14, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 5), (df['visits'].shift(-7) - df['Baseline']) * .11, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 6), (df['visits'].shift(-7) - df['Baseline']) * .10, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 1) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 7), (df['visits'].shift(-7) - df['Baseline']) * .09, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 0), (df['visits'].shift(-7) - df['Baseline']) * .41, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 1), (df['visits'].shift(-7) - df['Baseline']) * .27, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 2), (df['visits'].shift(-7) - df['Baseline']) * .20, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 3), (df['visits'].shift(-7) - df['Baseline']) * .15, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 4), (df['visits'].shift(-7) - df['Baseline']) * .13, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 5), (df['visits'].shift(-7) - df['Baseline']) * .11, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 6), (df['visits'].shift(-7) - df['Baseline']) * .09, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 2) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 7), (df['visits'].shift(-7) - df['Baseline']) * .08, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 0), (df['visits'].shift(-7) - df['Baseline']) * .32, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 1), (df['visits'].shift(-7) - df['Baseline']) * .22, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 2), (df['visits'].shift(-7) - df['Baseline']) * .17, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 3), (df['visits'].shift(-7) - df['Baseline']) * .14, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 4), (df['visits'].shift(-7) - df['Baseline']) * .12, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 5), (df['visits'].shift(-7) - df['Baseline']) * .10, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 6), (df['visits'].shift(-7) - df['Baseline']) * .09, df['attribute_7'])

df['attribute_7'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) + 
                              df['Ads'].shift(3) == 3) & (df['Ads'].shift(-1) + 
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) + 
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) == 7), (df['visits'].shift(-7) - df['Baseline']) * .08, df['attribute_7'])

# %% [markdown]
# Logic for 8th attribution

# %%
df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 0), df['visits'].shift(-8) - df['Baseline'], 0)

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 1), (df['visits'].shift(-8) - df['Baseline']) * .41, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 2), (df['visits'].shift(-8) - df['Baseline']) * .26, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 3), (df['visits'].shift(-8) - df['Baseline']) * .19, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 4), (df['visits'].shift(-8) - df['Baseline']) * .15, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 5), (df['visits'].shift(-8) - df['Baseline']) * .12, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 6), (df['visits'].shift(-8) - df['Baseline']) * .10, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 7), (df['visits'].shift(-8) - df['Baseline']) * .09, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 0) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 8), (df['visits'].shift(-8) - df['Baseline']) * .08, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 0), (df['visits'].shift(-8) - df['Baseline']) * .59, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 1), (df['visits'].shift(-8) - df['Baseline']) * .33, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 2), (df['visits'].shift(-8) - df['Baseline']) * .22, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 3), (df['visits'].shift(-8) - df['Baseline']) * .17, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 4), (df['visits'].shift(-8) - df['Baseline']) * .14, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 5), (df['visits'].shift(-8) - df['Baseline']) * .11, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 6), (df['visits'].shift(-8) - df['Baseline']) * .10, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 7), (df['visits'].shift(-8) - df['Baseline']) * .09, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 1) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 8), (df['visits'].shift(-8) - df['Baseline']) * .08, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 0), (df['visits'].shift(-8) - df['Baseline']) * .41, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 1), (df['visits'].shift(-8) - df['Baseline']) * .27, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 2), (df['visits'].shift(-8) - df['Baseline']) * .20, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 3), (df['visits'].shift(-8) - df['Baseline']) * .15, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 4), (df['visits'].shift(-8) - df['Baseline']) * .13, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 5), (df['visits'].shift(-8) - df['Baseline']) * .11, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 6), (df['visits'].shift(-8) - df['Baseline']) * .09, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 7), (df['visits'].shift(-8) - df['Baseline']) * .08, df['attribute_8'])

df['attribute_8'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) + df['Ads'].shift(2) == 2) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) + 
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) == 8), (df['visits'].shift(-8) - df['Baseline']) * .07, df['attribute_8'])

# %% [markdown]
# Logic for 9th attribution

# %%
df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 0), df['visits'].shift(-9) - df['Baseline'], 0)

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 1), (df['visits'].shift(-9) - df['Baseline']) * .41, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 2), (df['visits'].shift(-9) - df['Baseline']) * .26, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 3), (df['visits'].shift(-9) - df['Baseline']) * .19, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 4), (df['visits'].shift(-9) - df['Baseline']) * .15, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 5), (df['visits'].shift(-9) - df['Baseline']) * .12, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 6), (df['visits'].shift(-9) - df['Baseline']) * .10, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 7), (df['visits'].shift(-9) - df['Baseline']) * .09, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 8), (df['visits'].shift(-9) - df['Baseline']) * .08, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 0) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 9), (df['visits'].shift(-9) - df['Baseline']) * .07, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 0), (df['visits'].shift(-9) - df['Baseline']) * .59, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 1), (df['visits'].shift(-9) - df['Baseline']) * .33, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 2), (df['visits'].shift(-9) - df['Baseline']) * .22, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 3), (df['visits'].shift(-9) - df['Baseline']) * .17, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 4), (df['visits'].shift(-9) - df['Baseline']) * .14, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 5), (df['visits'].shift(-9) - df['Baseline']) * .11, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 6), (df['visits'].shift(-9) - df['Baseline']) * .10, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 7), (df['visits'].shift(-9) - df['Baseline']) * .09, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 8), (df['visits'].shift(-9) - df['Baseline']) * .08, df['attribute_9'])

df['attribute_9'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(1) == 1) & (df['Ads'].shift(-1) +
                              df['Ads'].shift(-2) + df['Ads'].shift(-3) +
                              df['Ads'].shift(-4) + df['Ads'].shift(-5) + 
                              df['Ads'].shift(-6) + df['Ads'].shift(-7) + 
                              df['Ads'].shift(-8) + df['Ads'].shift(-9) == 9), (df['visits'].shift(-9) - df['Baseline']) * .07, df['attribute_9'])

# %% [markdown]
# Logic for 10th Attribution

# %%
df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 0), df['visits'].shift(-10) - df['Baseline'], 0)

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 1), (df['visits'].shift(-10) - df['Baseline']) * .41, df['attribute_10'])

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 2), (df['visits'].shift(-10) - df['Baseline']) * .26, df['attribute_10'])

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 3), (df['visits'].shift(-10) - df['Baseline']) * .19, df['attribute_10'])

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 4), (df['visits'].shift(-10) - df['Baseline']) * .15, df['attribute_10'])

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 5), (df['visits'].shift(-10) - df['Baseline']) * .12, df['attribute_10'])

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 6), (df['visits'].shift(-10) - df['Baseline']) * .10, df['attribute_10'])

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 7), (df['visits'].shift(-10) - df['Baseline']) * .09, df['attribute_10'])

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 8), (df['visits'].shift(-10) - df['Baseline']) * .08, df['attribute_10'])

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 9), (df['visits'].shift(-10) - df['Baseline']) * .07, df['attribute_10'])

df['attribute_10'] = np.where((df['Ad_played'] == True) & 
                             (df['Ads'].shift(-1) + df['Ads'].shift(-2) +
                              df['Ads'].shift(-3) + df['Ads'].shift(-4) +
                              df['Ads'].shift(-5) + df['Ads'].shift(-6) + 
                              df['Ads'].shift(-7) + df['Ads'].shift(-8) + 
                              df['Ads'].shift(-9) + df['Ads'].shift(-10) == 10), (df['visits'].shift(-10) - df['Baseline']) * .07, df['attribute_10'])

# %%
df['attribute_0'] = np.where(df['attribute_0'] < 0, 0, df['attribute_0'])
df['attribute_1'] = np.where(df['attribute_1'] < 0, 0, df['attribute_1'])
df['attribute_2'] = np.where(df['attribute_2'] < 0, 0, df['attribute_2'])
df['attribute_3'] = np.where(df['attribute_3'] < 0, 0, df['attribute_3'])
df['attribute_4'] = np.where(df['attribute_4'] < 0, 0, df['attribute_4'])
df['attribute_5'] = np.where(df['attribute_5'] < 0, 0, df['attribute_5'])
df['attribute_6'] = np.where(df['attribute_6'] < 0, 0, df['attribute_6'])
df['attribute_7'] = np.where(df['attribute_7'] < 0, 0, df['attribute_7'])
df['attribute_8'] = np.where(df['attribute_8'] < 0, 0, df['attribute_8'])
df['attribute_9'] = np.where(df['attribute_9'] < 0, 0, df['attribute_9'])
df['attribute_10'] = np.where(df['attribute_10'] < 0, 0, df['attribute_10'])

# %%
df['total_attribute'] = df['attribute_0'] + df['attribute_1'] + df['attribute_2'] + df['attribute_3'] + df['attribute_4'] + df['attribute_5'] + df['attribute_6'] + df['attribute_7'] + df['attribute_8'] + df['attribute_9'] + df['attribute_10']

# %%
pd.set_option('display.max_rows', None)
df[800:1500]

# %%
pandas_gbq.to_gbq(df, 'Spike_Attribution_Model.q3_sepinc_2020_all_DMA_final', project_id=project_id, if_exists = 'replace')
